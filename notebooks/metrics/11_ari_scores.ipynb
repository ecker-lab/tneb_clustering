# %% [markdown]
# # ARI scores for the precomputed datasets and clustering algorithms

# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# %%
import corc.our_datasets
import corc.our_algorithms
from tqdm import tqdm
import pickle
import sklearn
import numpy as np
import pandas

# %%
datasets_2d = corc.our_datasets.DATASETS2D
algorithms = corc.our_algorithms.ALGORITHM_SELECTOR
datasets_2d
# Out:
# ['noisy_circles', 'noisy_moons', 'blobs', 'varied', 'aniso', 'clusterlab10']

# %%
# !! pwd
# Out:
# ['/scratch-grete/usr/nimmr000/git/cluster_vs_continuum/notebooks/metrics']

# %%
cache_path = "../../cache"

# %%
def check_missing_files(datasets,algorithms, cache_path="../../cache"):
    missing_files = []
    for dataset_name in datasets:
        dataset_filename = f"{cache_path}/{dataset_name}.pickle"
        if not os.path.exists(dataset_filename):
            missing_files.append(dataset_filename)

        for algorithm_name in algorithms:
            algorithm_name = algorithm_name.replace("\\n", "\n").replace("\n", "")
            alg_filename = f"{cache_path}/{dataset_name}_{algorithm_name}.pickle"
            if not os.path.exists(alg_filename):
                missing_files.append(alg_filename)
    return missing_files

# %%
def compute_ari_scores(datasets,algorithms, cache_path="../../cache"):
    ari_scores = np.zeros((len(datasets),len(algorithms)))
    for i_dataset, dataset_name in enumerate(tqdm(datasets)):
        dataset_filename = f"{cache_path}/{dataset_name}.pickle"
        with open(dataset_filename, "rb") as f:
            dataset_info = pickle.load(f)
            
        X, y = dataset_info["dataset"]
        
        for i_algorithm, algorithm_name in enumerate(algorithms):
            alg_name = algorithm_name.replace("\\n", "\n").replace("\n", "")
            alg_filename = f"{cache_path}/{dataset_name}_{alg_name}.pickle"
            if not os.path.exists(alg_filename):
                print("skipping", alg_filename)
                ari_scores[i_dataset,i_algorithm] = -1.
                continue
            with open(alg_filename, "rb") as f:
                algorithm = pickle.load(f)

            # extract predictions
            num_classes = len(np.unique(y))
            if isinstance(algorithm, corc.graph_metrics.gwgmara.GWGMara):
                y_pred = algorithm.predict(X, target_number_clusters=num_classes)
            elif hasattr(algorithm, "labels_"):
                y_pred = algorithm.labels_.astype(int)
            elif hasattr(algorithm, "predict_with_target"):
                y_pred = algorithm.predict_with_target(X, num_classes).astype(int)
            else:
                y_pred = algorithm.predict(X)

            ari_scores[i_dataset,i_algorithm] = sklearn.metrics.adjusted_rand_score(y, y_pred)
    df = pandas.DataFrame(ari_scores.transpose())
    df.columns = datasets # sets names for the axes
    df.index = algorithms
    return df

# %%
def style_dataFrame(df):

    def red_green_scale(val):
        if val < 0:
            return f'background-color: rgba(255, 0, 0, {abs(val)})'  # Red, alpha scales with magnitude
        elif val > 0:
            return f'background-color: rgba(0, 128, 0, {val})'      # Green, alpha scales with magnitude
        else:
            return ''  # White (default background)
    
    # df_nlargest = df.style.apply(lambda x: ['background-color: yellow' if v == x.nlargest(1).iloc[0] else '' for v in x], axis=0).format("{:.2f}")
    df_nlargest = df.style.apply(lambda x: ['background-color: yellow' if v == x.nlargest(1).iloc[0] else '' for v in x], axis=0).format("{:.2f}")

    styled_df = df.style.applymap(red_green_scale).format("{:.2f}")

    return styled_df

# %%
check_missing_files(datasets_2d,algorithms)
# Out:
# []

# %%
ari_scores_2d = compute_ari_scores(datasets_2d,algorithms)
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 22.60it/s]

# %%
style_dataFrame(ari_scores_2d)
# Out:
# /scratch/tmp/nimmr000/ipykernel_3824507/4247793715.py:14: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df.style.applymap(red_green_scale).format("{:.2f}")
# <style type="text/css">
# #T_3bfdc_row0_col0 {
#   background-color: rgba(255, 0, 0, 0.0009018997959843695);
# }
# #T_3bfdc_row0_col1 {
#   background-color: rgba(0, 128, 0, 0.483899912311112);
# }
# #T_3bfdc_row0_col2, #T_3bfdc_row6_col2, #T_3bfdc_row7_col2 {
#   background-color: rgba(0, 128, 0, 0.9821173784975067);
# }
# #T_3bfdc_row0_col3 {
#   background-color: rgba(0, 128, 0, 0.8405795791613532);
# }
# #T_3bfdc_row0_col4 {
#   background-color: rgba(0, 128, 0, 0.5874188186753246);
# }
# #T_3bfdc_row0_col5, #T_3bfdc_row1_col5, #T_3bfdc_row2_col0, #T_3bfdc_row2_col1, #T_3bfdc_row2_col5, #T_3bfdc_row3_col5, #T_3bfdc_row4_col5, #T_3bfdc_row5_col0, #T_3bfdc_row5_col1, #T_3bfdc_row8_col0, #T_3bfdc_row8_col1, #T_3bfdc_row8_col5, #T_3bfdc_row9_col0, #T_3bfdc_row9_col1, #T_3bfdc_row9_col5, #T_3bfdc_row11_col1, #T_3bfdc_row11_col5, #T_3bfdc_row12_col1, #T_3bfdc_row12_col5 {
#   background-color: rgba(0, 128, 0, 1.0);
# }
# #T_3bfdc_row1_col0 {
#   background-color: rgba(255, 0, 0, 0.0009204898405442519);
# }
# #T_3bfdc_row1_col1 {
#   background-color: rgba(0, 128, 0, 0.3739288935983808);
# }
# #T_3bfdc_row1_col2, #T_3bfdc_row8_col2, #T_3bfdc_row9_col2 {
#   background-color: rgba(0, 128, 0, 0.9645613288567468);
# }
# #T_3bfdc_row1_col3 {
#   background-color: rgba(0, 128, 0, 0.9500046546302245);
# }
# #T_3bfdc_row1_col4 {
#   background-color: rgba(0, 128, 0, 0.5303329768442275);
# }
# #T_3bfdc_row2_col2 {
#   background-color: rgba(0, 128, 0, 0.5702013104999563);
# }
# #T_3bfdc_row2_col3 {
#   background-color: rgba(0, 128, 0, 0.9183499393767444);
# }
# #T_3bfdc_row2_col4 {
#   background-color: rgba(0, 128, 0, 0.8862315977339812);
# }
# #T_3bfdc_row3_col0 {
#   background-color: rgba(255, 0, 0, 0.00090186770293864);
# }
# #T_3bfdc_row3_col1 {
#   background-color: rgba(0, 128, 0, 0.49793352946395614);
# }
# #T_3bfdc_row3_col2, #T_3bfdc_row4_col2 {
#   background-color: rgba(0, 128, 0, 0.9791686930598544);
# }
# #T_3bfdc_row3_col3, #T_3bfdc_row4_col3 {
#   background-color: rgba(0, 128, 0, 0.9470060670133185);
# }
# #T_3bfdc_row3_col4, #T_3bfdc_row4_col4 {
#   background-color: rgba(0, 128, 0, 0.9970015045323003);
# }
# #T_3bfdc_row4_col0 {
#   background-color: rgba(255, 0, 0, 0.0007421376035116506);
# }
# #T_3bfdc_row4_col1 {
#   background-color: rgba(0, 128, 0, 0.14846495922267824);
# }
# #T_3bfdc_row5_col2 {
#   background-color: rgba(0, 128, 0, 0.9674247207916085);
# }
# #T_3bfdc_row5_col3 {
#   background-color: rgba(0, 128, 0, 0.9499695883499413);
# }
# #T_3bfdc_row5_col4 {
#   background-color: rgba(0, 128, 0, 0.853370060071221);
# }
# #T_3bfdc_row5_col5 {
#   background-color: rgba(0, 128, 0, 0.6771774337200045);
# }
# #T_3bfdc_row6_col0 {
#   background-color: rgba(255, 0, 0, 0.0014913377945307332);
# }
# #T_3bfdc_row6_col1 {
#   background-color: rgba(0, 128, 0, 0.46841829921315414);
# }
# #T_3bfdc_row6_col3 {
#   background-color: rgba(0, 128, 0, 0.8126101333687344);
# }
# #T_3bfdc_row6_col4 {
#   background-color: rgba(0, 128, 0, 0.5944683128002282);
# }
# #T_3bfdc_row6_col5 {
#   background-color: rgba(0, 128, 0, 0.47405452946350046);
# }
# #T_3bfdc_row7_col0 {
#   background-color: rgba(0, 128, 0, 0.010765287690553897);
# }
# #T_3bfdc_row7_col1 {
#   background-color: rgba(0, 128, 0, 0.5412367775551102);
# }
# #T_3bfdc_row7_col3 {
#   background-color: rgba(0, 128, 0, 0.8643182112875629);
# }
# #T_3bfdc_row7_col4 {
#   background-color: rgba(0, 128, 0, 0.5152607685618071);
# }
# #T_3bfdc_row7_col5 {
#   background-color: rgba(0, 128, 0, 0.530626889679411);
# }
# #T_3bfdc_row8_col3 {
#   background-color: rgba(0, 128, 0, 0.955734223808089);
# }
# #T_3bfdc_row8_col4 {
#   background-color: rgba(0, 128, 0, 0.5937632563267324);
# }
# #T_3bfdc_row9_col4 {
#   background-color: rgba(0, 128, 0, 0.9026743417324012);
# }
# #T_3bfdc_row10_col0 {
#   background-color: rgba(0, 128, 0, 0.09439158243413753);
# }
# #T_3bfdc_row10_col1 {
#   background-color: rgba(0, 128, 0, 0.07032676456275674);
# }
# #T_3bfdc_row10_col2 {
#   background-color: rgba(0, 128, 0, 0.9732987772679587);
# }
# #T_3bfdc_row10_col3 {
#   background-color: rgba(0, 128, 0, 0.9528806554641642);
# }
# #T_3bfdc_row10_col4 {
#   background-color: rgba(0, 128, 0, 0.9940030181141498);
# }
# #T_3bfdc_row10_col5 {
#   background-color: rgba(0, 128, 0, 0.7815833047238802);
# }
# #T_3bfdc_row11_col0, #T_3bfdc_row12_col0 {
#   background-color: rgba(0, 128, 0, 0.995999996008016);
# }
# #T_3bfdc_row11_col2 {
#   background-color: rgba(0, 128, 0, 0.9674262936148178);
# }
# #T_3bfdc_row11_col3 {
#   background-color: rgba(0, 128, 0, 0.8991179921247225);
# }
# #T_3bfdc_row11_col4 {
#   background-color: rgba(0, 128, 0, 0.9910135858709991);
# }
# #T_3bfdc_row12_col2 {
#   background-color: rgba(0, 128, 0, 0.9674656426335413);
# }
# #T_3bfdc_row12_col3 {
#   background-color: rgba(0, 128, 0, 0.9557319532201247);
# }
# #T_3bfdc_row12_col4 {
#   background-color: rgba(0, 128, 0, 0.9821452406759336);
# }
# </style>
# <table id="T_3bfdc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bfdc_level0_col0" class="col_heading level0 col0" >noisy_circles</th>
#       <th id="T_3bfdc_level0_col1" class="col_heading level0 col1" >noisy_moons</th>
#       <th id="T_3bfdc_level0_col2" class="col_heading level0 col2" >blobs</th>
#       <th id="T_3bfdc_level0_col3" class="col_heading level0 col3" >varied</th>
#       <th id="T_3bfdc_level0_col4" class="col_heading level0 col4" >aniso</th>
#       <th id="T_3bfdc_level0_col5" class="col_heading level0 col5" >clusterlab10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bfdc_level0_row0" class="row_heading level0 row0" >MiniBatch
# KMeans</th>
#       <td id="T_3bfdc_row0_col0" class="data row0 col0" >-0.00</td>
#       <td id="T_3bfdc_row0_col1" class="data row0 col1" >0.48</td>
#       <td id="T_3bfdc_row0_col2" class="data row0 col2" >0.98</td>
#       <td id="T_3bfdc_row0_col3" class="data row0 col3" >0.84</td>
#       <td id="T_3bfdc_row0_col4" class="data row0 col4" >0.59</td>
#       <td id="T_3bfdc_row0_col5" class="data row0 col5" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_3bfdc_level0_row1" class="row_heading level0 row1" >Agglomerative
# Clustering</th>
#       <td id="T_3bfdc_row1_col0" class="data row1 col0" >-0.00</td>
#       <td id="T_3bfdc_row1_col1" class="data row1 col1" >0.37</td>
#       <td id="T_3bfdc_row1_col2" class="data row1 col2" >0.96</td>
#       <td id="T_3bfdc_row1_col3" class="data row1 col3" >0.95</td>
#       <td id="T_3bfdc_row1_col4" class="data row1 col4" >0.53</td>
#       <td id="T_3bfdc_row1_col5" class="data row1 col5" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_3bfdc_level0_row2" class="row_heading level0 row2" >HDBSCAN</th>
#       <td id="T_3bfdc_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_3bfdc_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_3bfdc_row2_col2" class="data row2 col2" >0.57</td>
#       <td id="T_3bfdc_row2_col3" class="data row2 col3" >0.92</td>
#       <td id="T_3bfdc_row2_col4" class="data row2 col4" >0.89</td>
#       <td id="T_3bfdc_row2_col5" class="data row2 col5" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_3bfdc_level0_row3" class="row_heading level0 row3" >Gaussian
# Mixture</th>
#       <td id="T_3bfdc_row3_col0" class="data row3 col0" >-0.00</td>
#       <td id="T_3bfdc_row3_col1" class="data row3 col1" >0.50</td>
#       <td id="T_3bfdc_row3_col2" class="data row3 col2" >0.98</td>
#       <td id="T_3bfdc_row3_col3" class="data row3 col3" >0.95</td>
#       <td id="T_3bfdc_row3_col4" class="data row3 col4" >1.00</td>
#       <td id="T_3bfdc_row3_col5" class="data row3 col5" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_3bfdc_level0_row4" class="row_heading level0 row4" >t-Student
# Mixture</th>
#       <td id="T_3bfdc_row4_col0" class="data row4 col0" >-0.00</td>
#       <td id="T_3bfdc_row4_col1" class="data row4 col1" >0.15</td>
#       <td id="T_3bfdc_row4_col2" class="data row4 col2" >0.98</td>
#       <td id="T_3bfdc_row4_col3" class="data row4 col3" >0.95</td>
#       <td id="T_3bfdc_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_3bfdc_row4_col5" class="data row4 col5" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_3bfdc_level0_row5" class="row_heading level0 row5" >Spectral
# Clustering</th>
#       <td id="T_3bfdc_row5_col0" class="data row5 col0" >1.00</td>
#       <td

# %% [markdown]
# # high-dimensional datasets

# %%
complex_datasets = corc.our_datasets.COMPLEX_DATASETS
complex_datasets
# Out:
# ['blobs1_8',
#  'blobs1_16',
#  'blobs1_32',
#  'blobs1_64',
#  'blobs2_8',
#  'blobs2_16',
#  'blobs2_32',
#  'blobs2_64',
#  'densired8',
#  'densired16',
#  'densired32',
#  'densired64',
#  'densired_soft_8',
#  'densired_soft_16',
#  'densired_soft_32',
#  'densired_soft_64',
#  'mnist8',
#  'mnist16',
#  'mnist32',
#  'mnist64']

# %%
check_missing_files(complex_datasets,algorithms)
# Out:
# ['../../cache/blobs2_64_TMM-NEB.pickle']

# %%
ari_scores_complex = compute_ari_scores(complex_datasets,algorithms)
# Out:
#  25%|██▌       | 5/20 [00:00<00:00, 17.78it/s]
# 6 clusters is not achievable.
# Working with 2 clusters instead.
# 6 clusters is not achievable.
# Working with 3 clusters instead.
#  35%|███▌      | 7/20 [00:00<00:00, 15.90it/s]
# skipping ../../cache/blobs2_64_TMM-NEB.pickle
# 6 clusters is not achievable.
# Working with 3 clusters instead.
# 100%|██████████| 20/20 [00:07<00:00,  2.85it/s]

# %%
style_dataFrame(ari_scores_complex)
# Out:
# /scratch/tmp/nimmr000/ipykernel_3824507/4247793715.py:14: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df.style.applymap(red_green_scale).format("{:.2f}")
# <style type="text/css">
# #T_ea544_row0_col0 {
#   background-color: rgba(0, 128, 0, 0.6489900395691355);
# }
# #T_ea544_row0_col1 {
#   background-color: rgba(0, 128, 0, 0.6778238472695665);
# }
# #T_ea544_row0_col2 {
#   background-color: rgba(0, 128, 0, 0.9364279595878581);
# }
# #T_ea544_row0_col3 {
#   background-color: rgba(0, 128, 0, 0.7297171207509956);
# }
# #T_ea544_row0_col4 {
#   background-color: rgba(0, 128, 0, 0.555930880966252);
# }
# #T_ea544_row0_col5 {
#   background-color: rgba(0, 128, 0, 0.3353231996441729);
# }
# #T_ea544_row0_col6 {
#   background-color: rgba(0, 128, 0, 0.3734150997726685);
# }
# #T_ea544_row0_col7 {
#   background-color: rgba(0, 128, 0, 0.5769483308578942);
# }
# #T_ea544_row0_col8 {
#   background-color: rgba(0, 128, 0, 0.6285260416704523);
# }
# #T_ea544_row0_col9 {
#   background-color: rgba(0, 128, 0, 0.632946506878763);
# }
# #T_ea544_row0_col10 {
#   background-color: rgba(0, 128, 0, 0.497777061664001);
# }
# #T_ea544_row0_col11 {
#   background-color: rgba(0, 128, 0, 0.7353706895150928);
# }
# #T_ea544_row0_col12 {
#   background-color: rgba(0, 128, 0, 0.6313146281549271);
# }
# #T_ea544_row0_col13 {
#   background-color: rgba(0, 128, 0, 0.49455802754272254);
# }
# #T_ea544_row0_col14 {
#   background-color: rgba(0, 128, 0, 0.5296600218019772);
# }
# #T_ea544_row0_col15 {
#   background-color: rgba(0, 128, 0, 0.4913591418614766);
# }
# #T_ea544_row0_col16 {
#   background-color: rgba(0, 128, 0, 0.5678718904045752);
# }
# #T_ea544_row0_col17 {
#   background-color: rgba(0, 128, 0, 0.44475946415177436);
# }
# #T_ea544_row0_col18 {
#   background-color: rgba(0, 128, 0, 0.3163640171160636);
# }
# #T_ea544_row0_col19 {
#   background-color: rgba(0, 128, 0, 0.26091892857938087);
# }
# #T_ea544_row1_col0 {
#   background-color: rgba(0, 128, 0, 0.7341425367629494);
# }
# #T_ea544_row1_col1 {
#   background-color: rgba(0, 128, 0, 0.8316449810182905);
# }
# #T_ea544_row1_col2 {
#   background-color: rgba(0, 128, 0, 0.8024521428789025);
# }
# #T_ea544_row1_col3 {
#   background-color: rgba(0, 128, 0, 0.7964683487833671);
# }
# #T_ea544_row1_col4 {
#   background-color: rgba(0, 128, 0, 0.5488846856991216);
# }
# #T_ea544_row1_col5 {
#   background-color: rgba(0, 128, 0, 0.6461996928987193);
# }
# #T_ea544_row1_col6 {
#   background-color: rgba(0, 128, 0, 0.5363558981491858);
# }
# #T_ea544_row1_col7 {
#   background-color: rgba(0, 128, 0, 0.5178483612576867);
# }
# #T_ea544_row1_col8 {
#   background-color: rgba(0, 128, 0, 0.6833788657120411);
# }
# #T_ea544_row1_col9 {
#   background-color: rgba(0, 128, 0, 0.6639463003354714);
# }
# #T_ea544_row1_col10 {
#   background-color: rgba(0, 128, 0, 0.5877790990262606);
# }
# #T_ea544_row1_col11 {
#   background-color: rgba(0, 128, 0, 0.7494897218265404);
# }
# #T_ea544_row1_col12 {
#   background-color: rgba(0, 128, 0, 0.5648099352464075);
# }
# #T_ea544_row1_col13 {
#   background-color: rgba(0, 128, 0, 0.8688760189198833);
# }
# #T_ea544_row1_col14 {
#   background-color: rgba(0, 128, 0, 0.9029120660490106);
# }
# #T_ea544_row1_col15 {
#   background-color: rgba(0, 128, 0, 0.6394295358369777);
# }
# #T_ea544_row1_col16 {
#   background-color: rgba(0, 128, 0, 0.802269717409956);
# }
# #T_ea544_row1_col17 {
#   background-color: rgba(0, 128, 0, 0.6800936857959954);
# }
# #T_ea544_row1_col18 {
#   background-color: rgba(0, 128, 0, 0.6169339986389509);
# }
# #T_ea544_row1_col19 {
#   background-color: rgba(0, 128, 0, 0.48785899966426016);
# }
# #T_ea544_row2_col0 {
#   background-color: rgba(0, 128, 0, 0.004507809806946138);
# }
# #T_ea544_row2_col1 {
#   background-color: rgba(0, 128, 0, 0.0010634842980611365);
# }
# #T_ea544_row2_col2 {
#   background-color: rgba(0, 128, 0, 0.0008449626926643418);
# }
# #T_ea544_row2_col3 {
#   background-color: rgba(0, 128, 0, 0.0009483385960313841);
# }
# #T_ea544_row2_col4 {
#   background-color: rgba(0, 128, 0, 0.2266412656758677);
# }
# #T_ea544_row2_col5 {
#   background-color: rgba(0, 128, 0, 0.07571056298759747);
# }
# #T_ea544_row2_col6 {
#   background-color: rgba(255, 0, 0, 0.03198996405509259);
# }
# #T_ea544_row2_col7 {
#   background-color: rgba(255, 0, 0, 0.019800371180005456);
# }
# #T_ea544_row2_col8 {
#   background-color: rgba(0, 128, 0, 0.0002898054873148955);
# }
# #T_ea544_row2_col9 {
#   background-color: rgba(0, 128, 0, 0.0004485507353349889);
# }
# #T_ea544_row2_col10 {
#   background-color: rgba(0, 128, 0, 0.4353376876549222);
# }
# #T_ea544_row2_col12 {
#   background-color: rgba(0, 128, 0, 0.006175556202089479);
# }
# #T_ea544_row2_col13 {
#   background-color: rgba(0, 128, 0, 0.0030081688010899416);
# }
# #T_ea544_row2_col14 {
#   background-color: rgba(0, 128, 0, 0.0011860096176229548);
# }
# #T_ea544_row2_col15 {
#   background-color: rgba(0, 128, 0, 0.0009104627684688752);
# }
# #T_ea544_row2_col16 {
#   background-color: rgba(0, 128, 0, 0.020657988805186926);
# }
# #T_ea544_row2_col17 {
#   background-color: rgba(0, 128, 0, 0.032252643304299784);
# }
# #T_ea544_row2_col18 {
#   background-color: rgba(0, 128, 0, 0.04955513655553754);
# }
# #T_ea544_row2_col19 {
#   background-color: rgba(0, 128, 0, 0.050714713608443714);
# }
# #T_ea544_row3_col0 {
#   background-color: rgba(0, 128, 0, 0.6930604917156694);
# }
# #T_ea544_row3_col1 {
#   background-color: rgba(0, 128, 0, 0.9200473563958057);
# }
# #T_ea544_row3_col2 {
#   background-color: rgba(0, 128, 0, 0.9179665986362574);
# }
# #T_ea544_row3_col3 {
#   background-color: rgba(0, 128, 0, 0.721952813263372);
# }
# #T_ea544_row3_col4 {
#   background-color: rgba(0, 128, 0, 0.3732797180924435);
# }
# #T_ea544_row3_col5 {
#   background-color: rgba(0, 128, 0, 0.5258516935287744);
# }
# #T_ea544_row3_col6 {
#   background-color: rgba(0, 128, 0, 0.36531485105450195);
# }
# #T_ea544_row3_col7 {
#   background-color: rgba(0, 128, 0, 0.5664709135559476);
# }
# #T_ea544_row3_col8 {
#   background-color: rgba(0, 128, 0, 0.45517221008370984);
# }
# #T_ea544_row3_col9 {
#   background-color: rgba(0, 128, 0, 0.627439566612944);
# }
# #T_ea544_row3_col10 {
#   background-color: rgba(0, 128, 0, 0.4954677421777471);
# }
# #T_ea544_row3_col11 {
#   background-color: rgba(0, 128, 0, 0.6420204188899054);
# }
# #T_ea544_row3_col12 {
#   background-color: rgba(0, 128, 0, 0.39728151094182523);
# }
# #T_ea544_row3_col13 {
#   background-color: rgba(0, 128, 0, 0.5418957953813061);
# }
# #T_ea544_row3_col14 {
#   background-color: rgba(0, 128, 0, 0.4082363024434504);
# }
# #T_ea544_row3_col15 {
#   background-color: rgba(0, 128, 0, 0.425122822226942);
# }
# #T_ea544_row3_col16 {
#   background-color: rgba(0, 128, 0, 0.7503417400201775);
# }
# #T_ea544_row3_col17 {
#   background-color: rgba(0, 128, 0, 0.7105285795139857);
# }
# #T_ea544_row3_col18 {
#   background-color: rgba(0, 128, 0, 0.6159760734274367);
# }
# #T_ea544_row3_col19 {
#   background-color: rgba(0, 128, 0, 0.5666123223111629);
# }
# #T_ea544_row4_col0 {
#   background-color: rgba(0, 128, 0, 0.7109436436452499);
# }
# #T_ea544_row4_col1 {
#   background-color: rgba(0, 128, 0, 0.696140210764834);
# }
# #T_ea544_row4_col2 {
#   background-color: rgba(0, 128, 0, 0.23088676805601677);
# }
# #T_ea544_row4_col3 {
#   background-color: rgba(0, 128, 0, 0.02828279216807956);
# }
# #T_ea544_row4_col4 {
#   background-color: rgba(0, 128, 0, 0.5619789897540692);
# }
# #T_ea544_row4_col5 {
#   background-color: rgba(0, 128, 0, 0.6486194765428585);
# }
# #T_ea544_row4_col6 {
#   background-color: rgba(0, 128, 0, 0.10185455884239494);
# }
# #T_ea544_row4_col7 {
#   background-color: rgba(0, 128, 0, 0.06807839573603418);
# }
# #T_ea544_row4_col8 {
#   background-color: rgba(0, 128, 0, 0.6642148216473855);
# }
# #T_ea544_row4_col9 {
#   background-color: rgba(0, 128, 0, 0.6612090023731496);
# }
# #T_ea544_row4_col10 {
#   background-color: rgba(0, 128, 0, 0.579954550703848);
# }
# #T_ea544_row4_col11 {
#   background-color: rgba(0, 128, 0, 0.631261636639775);
# }
# #T_ea544_row4_col12 {
#   background-color: rgba(0, 128, 0, 0.48887369909618056);
# }
# #T_ea544_row4_col13 {
#   background-color: rgba(0, 128, 0, 0.49651361789564386);
# }
# #T_ea544_row4_col14 {
#   background-color: rgba(0, 128, 0, 0.8995250578412702);
# }
# #T_ea544_row4_col15 {
#   background-color: rgba(0, 128, 0, 0.3887117688349461);
# }
# #T_ea544_row4_col16 {
#   background-color: rgba(0, 128, 0, 0.7633265815351761);
# }
# #T_ea544_row4_col17 {
#   background-color: rgba(0, 128, 0, 0.8992109618833523);
# }
# #T_ea544_row4_col18 {
#   background-color: rgba(0, 128, 0, 0.7701445744547899);
# }
# #T_ea544_row4_col19 {
#   background-color: rgba
