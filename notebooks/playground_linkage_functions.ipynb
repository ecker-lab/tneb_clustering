# %%
# Something is off with the linkage functions.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import corc.utils
# import corc
import matplotlib.pyplot as plt
import pickle
import corc.graph_metrics.uniforce
import corc.graph_metrics.neb
import numpy as np
import sklearn.metrics
import tqdm
import corc.our_datasets

# %%
dataset = "densired64"
X,y,tsne = corc.utils.load_dataset(dataset)
single_linkage  = corc.utils.load_algorithms(dataset, algorithm="SingleLinkage")
average_linkage = corc.utils.load_algorithms(dataset, algorithm="AverageLinkage")
complete_linkage = corc.utils.load_algorithms(dataset, algorithm="CompleteLinkage")

# %%
single = single_linkage[0]

# %%
y_pred = single.labels_

# %%
np.unique(y_pred, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([1766, 8230,    1,    1,    1,    1]))

# %%
np.unique(average_linkage[0].labels_, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([1766, 8230,    1,    1,    1,    1]))

# %%
plt.scatter(tsne[:,0], tsne[:,1], c=y_pred)

# %%
plt.scatter(tsne[:,0],tsne[:,1],c=average_linkage[0].labels_)

# %%
plt.scatter(tsne[:,0],tsne[:,1],c=complete_linkage[0].labels_)
