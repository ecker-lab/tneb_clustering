# %% [markdown]
# # ARI scores for the precomputed datasets and clustering algorithms

# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# %%
import corc.our_datasets
import corc.our_algorithms
from tqdm import tqdm
import pickle
import sklearn
import numpy as np
import pandas as pd

# %%
metrics_path = "../../cache/metrics/figure2.pkl"

with open(metrics_path, "rb") as f:
    metrics = pickle.load(f)

# %%
metrics.keys()
# Out:
# dict_keys(['densired8', 'densired16', 'densired32', 'densired64', 'densired_soft_8', 'densired_soft_16', 'densired_soft_32', 'densired_soft_64', 'mnist8', 'mnist16', 'mnist32', 'mnist64'])

# %%
dataset = "densired_soft_16"

# %%
df = pd.DataFrame(metrics[dataset])
df = df.T
df.columns = ['ARI (↑)', 'NMI (↑)', 'FM (↑)', 'VI (↓)']
df
# Out:
#                             ARI (↑)   NMI (↑)    FM (↑)    VI (↓)
# MiniBatch\nKMeans          0.840567  0.815357  0.885663  0.554340
# Agglomerative\nClustering  0.868876  0.811145  0.909662  0.498384
# HDBSCAN                    0.003837  0.004492  0.426383  1.968905
# Gaussian\nMixture          0.678238  0.659114  0.768717  0.941258
# t-Student\nMixture         0.897433  0.823379  0.927701  0.478697
# Spectral\nClustering       0.730798  0.804895  0.806364  0.599138
# Affinity\nPropagation      0.537887  0.564567  0.735970  0.913989
# MeanShift                  0.786306  0.682507  0.846020  1.053425
# Leiden                     0.934459  0.876579  0.953593  0.344912
# PAGA                       0.826939  0.781451  0.884944  0.544889
# UniForCE                   0.337621  0.498391  0.538822  1.421560
# SMMP                       0.281402  0.462585  0.486317  1.544002
# GWG-dip                    0.720461  0.691516  0.805104  0.825188
# GMM-NEB                    0.718244  0.680417  0.801033  0.909289
# TMM-NEB                    0.935757  0.871493  0.954389  0.360712

# %%
algorithms = ["Agglomerative\nClustering", "HDBSCAN", "t-Student\nMixture", "Gaussian\nMixture", "Leiden", "TMM-NEB"]
datasets = metrics.keys()
# datasets = ["densired8", "densired16", "densired32", "densired64", "densired_soft_8", "densired_soft_16", "densired_soft_32", "densired_soft_64", "mnist8", "mnist16", "mnist32", "mnist64"]

# %%
def create_dataframe(metrics, index, algorithms, datasets):
    df = pd.DataFrame({dataset: {algorithm: np.round(metrics[dataset][algorithm][index], decimals=2) for algorithm in metrics[dataset] if algorithm in algorithms} for dataset in datasets})
    alg_names = df.index.tolist()
    
    # rename algorithms
    for i in range(len(alg_names)):
        if alg_names[i] in corc.our_algorithms.ALG_DISPLAYNAMES.keys():
            alg_names[i] = corc.our_algorithms.ALG_DISPLAYNAMES[alg_names[i]]
    df.index = alg_names

    # rename datasets
    dataset_names = df.columns.tolist()
    for i in range(len(dataset_names)):
        if dataset_names[i] in corc.our_datasets.dataset_displaynames.keys():
            dataset_names[i] = corc.our_datasets.dataset_displaynames[dataset_names[i]]
    df.columns = dataset_names

    return df

# %%
ari_table = create_dataframe(metrics, 0, algorithms, datasets)
nmi_table = create_dataframe(metrics, 1, algorithms, datasets)
fm_table = create_dataframe(metrics, 2, algorithms, datasets)
vi_table = create_dataframe(metrics, 3, algorithms, datasets)

# %%
ari_table
# Out:
#                            Densired\n'circles' 8D  Densired\n'circles' 16D  \
# Agglomerative\nClustering                    0.68                     0.66
# HDBSCAN                                      0.00                     0.00
# Gaussian\nMixture                            0.79                     0.77
# Student-t\nMixture                           0.81                     0.69
# Leiden                                       0.83                     0.77
# t-NEB (ours)                                 0.92                     1.00
#
#                            Densired\n'circles' 32D  Densired\n'circles' 64D  \
# Agglomerative\nClustering                     0.59                     0.75
# HDBSCAN                                       0.44                     0.00
# Gaussian\nMixture                             0.69                     0.91
# Student-t\nMixture                            0.58                     0.61
# Leiden                                        0.76                     0.89
# t-NEB (ours)                                  0.94                     0.96
#
#                            Densired\n'Stud-t' 8D  Densired\n'Stud-t' 16D  \
# Agglomerative\nClustering                   0.56                    0.87
# HDBSCAN                                     0.01                    0.00
# Gaussian\nMixture                           0.74                    0.68
# Student-t\nMixture                          0.74                    0.90
# Leiden                                      0.89                    0.93
# t-NEB (ours)                                0.89                    0.94
#
#                            Densired\n'Stud-t' 32D  Densired\n'Stud-t' 64D  \
# Agglomerative\nClustering                    0.90                    0.64
# HDBSCAN                                      0.00                    0.00
# Gaussian\nMixture                            0.49                    0.42
# Student-t\nMixture                           0.90                    0.75
# Leiden                                       0.91                    0.80
# t-NEB (ours)                                 0.94                    0.74
#
#                            MNIST-Nd\n8D  MNIST-Nd\n16D  MNIST-Nd\n32D  \
# Agglomerative\nClustering          0.80           0.68           0.62
# HDBSCAN                            0.03           0.06           0.07
# Gaussian\nMixture                  0.89           0.74           0.73
# Student-t\nMixture                 0.85           0.86           0.90
# Leiden                             0.89           0.92           0.93
# t-NEB (ours)                       0.77           0.92           0.79
#
#                            MNIST-Nd\n64D
# Agglomerative\nClustering           0.49
# HDBSCAN                             0.07
# Gaussian\nMixture                   0.62
# Student-t\nMixture                  0.77
# Leiden                              0.71
# t-NEB (ours)                        0.64

# %%
ari_table = pd.DataFrame({dataset: {algorithm: np.round(metrics[dataset][algorithm][0], decimals=2) for algorithm in metrics[dataset] if algorithm in algorithms} for dataset in datasets})
nmi_table = pd.DataFrame({dataset: {algorithm: np.round(metrics[dataset][algorithm][1], decimals=2) for algorithm in metrics[dataset] if algorithm in algorithms} for dataset in datasets})
fm_table = pd.DataFrame({dataset: {algorithm: np.round(metrics[dataset][algorithm][2], decimals=2) for algorithm in metrics[dataset] if algorithm in algorithms} for dataset in datasets})
vi_table = pd.DataFrame({dataset: {algorithm: np.round(metrics[dataset][algorithm][3], decimals=2) for algorithm in metrics[dataset] if algorithm in algorithms} for dataset in datasets})

# %%
ari_table.index.tolist()
# Out:
# ['Agglomerative\nClustering',
#  'HDBSCAN',
#  'Gaussian\nMixture',
#  't-Student\nMixture',
#  'Leiden',
#  'TMM-NEB']

# %%
nmi_table
# Out:
#                            densired8  densired16  densired32  densired64  \
# Agglomerative\nClustering       0.82        0.82        0.79        0.84
# HDBSCAN                         0.00        0.00        0.59        0.00
# Gaussian\nMixture               0.83        0.90        0.84        0.93
# t-Student\nMixture              0.91        0.84        0.79        0.79
# Leiden                          0.91        0.90        0.90        0.93
# TMM-NEB                         0.93        1.00        0.95        0.96
#
#                            densired_soft_8  densired_soft_16  \
# Agglomerative\nClustering             0.59              0.81
# HDBSCAN                               0.00              0.00
# Gaussian\nMixture                     0.73              0.66
# t-Student\nMixture                    0.72              0.82
# Leiden                                0.82              0.88
# TMM-NEB                               0.82              0.87
#
#                            densired_soft_32  densired_soft_64  mnist8  \
# Agglomerative\nClustering              0.85              0.71    0.83
# HDBSCAN                                0.01              0.01    0.06
# Gaussian\nMixture                      0.56              0.46    0.89
# t-Student\nMixture                     0.84              0.71    0.86
# Leiden                                 0.86              0.81    0.89
# TMM-NEB                                0.88              0.75    0.85
#
#                            mnist16  mnist32  mnist64
# Agglomerative\nClustering     0.78     0.75     0.65
# HDBSCAN                       0.11     0.14     0.13
# Gaussian\nMixture             0.82     0.81     0.75
# t-Student\nMixture            0.87     0.89     0.84
# Leiden                        0.91     0.91     0.80
# TMM-NEB                       0.91     0.86     0.74

# %%
vi_table
# Out:
#                            densired8  densired16  densired32  densired64  \
# Agglomerative\nClustering       0.55        0.56        0.66        0.49
# HDBSCAN                         1.41        1.42        0.82        1.41
# Gaussian\nMixture               0.51        0.31        0.52        0.20
# t-Student\nMixture              0.27        0.51        0.67        0.68
# Leiden                          0.27        0.31        0.32        0.19
# TMM-NEB                         0.21        0.01        0.15        0.11
#
#                            densired_soft_8  densired_soft_16  \
# Agglomerative\nClustering             0.95              0.50
# HDBSCAN                               1.94              1.97
# Gaussian\nMixture                     0.79              0.94
# t-Student\nMixture                    0.82              0.48
# Leiden                                0.49              0.34
# TMM-NEB                               0.50              0.36
#
#                            densired_soft_32  densired_soft_64  mnist8  \
# Agglomerative\nClustering              0.41              0.65    0.78
# HDBSCAN                                1.97              2.07    2.80
# Gaussian\nMixture                      1.16              1.32    0.52
# t-Student\nMixture                     0.45              0.74    0.64
# Leiden                                 0.37              0.47    0.52
# TMM-NEB                                0.32              0.74    0.67
#
#                            mnist16  mnist32  mnist64
# Agglomerative\nClustering     1.00     1.12     1.57
# HDBSCAN                       2.65     2.59     2.60
# Gaussian\nMixture             0.80     0.86     1.15
# t-Student\nMixture            0.58     0.50     0.73
# Leiden                        0.41     0.40     0.88
# TMM-NEB                       0.43     0.63     1.16

# %%
# Color the top three values per column
def color_top3(val, series):
    if val in series.nlargest(3).values:
        if val == series.max():
            return 'background-color: lightgreen'
        elif val == series.nlargest(2).iloc[1]:
            return 'background-color: yellow'
        # elif val == series.nlargest(3).iloc[2]:
        #     return 'background-color: orange'
    else:
        return ''
    
# Color the top three values per column
def color_min3(val, series):
    if val in series.nsmallest(3).values:
        if val == series.nsmallest(1).iloc[0]:
            return 'background-color: lightgreen'
        elif val == series.nsmallest(2).iloc[1]:
            return 'background-color: yellow'
        # elif val == series.nsmallest(3).iloc[2]:
        #     return 'background-color: orange'
    else:
        return ''
    
def format_latex_output(latex_str):
    # Regular expression to match floating-point numbers
    pattern = r'({\\cellcolor{yellow}}|{\\cellcolor{lightgreen}})\s*([-+]?\d*\.\d+|\d+)'

    # Use re.sub to replace matched patterns with LaTeX formatting
    formatted_str = re.sub(
        pattern,
        lambda match: f'\\textit{{{match.group(2)}}}' if match.group(1) == '{\\cellcolor{yellow}}' else f'\\textbf{{{match.group(2)}}}',
        latex_str
    )

    return formatted_str

# %%
styled_ari = ari_table.style.apply(lambda x: x.apply(lambda y: color_top3(y, x))).format("{:.2f}")
styled_ari
# Out:
# <style type="text/css">
# #T_d5e70_row2_col1, #T_d5e70_row2_col3, #T_d5e70_row3_col7, #T_d5e70_row3_col10, #T_d5e70_row4_col0, #T_d5e70_row4_col1, #T_d5e70_row4_col2, #T_d5e70_row4_col5, #T_d5e70_row4_col6, #T_d5e70_row4_col11 {
#   background-color: yellow;
# }
# #T_d5e70_row2_col8, #T_d5e70_row3_col11, #T_d5e70_row4_col4, #T_d5e70_row4_col7, #T_d5e70_row4_col8, #T_d5e70_row4_col9, #T_d5e70_row4_col10, #T_d5e70_row5_col0, #T_d5e70_row5_col1, #T_d5e70_row5_col2, #T_d5e70_row5_col3, #T_d5e70_row5_col4, #T_d5e70_row5_col5, #T_d5e70_row5_col6, #T_d5e70_row5_col9 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d5e70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5e70_level0_col0" class="col_heading level0 col0" >densired8</th>
#       <th id="T_d5e70_level0_col1" class="col_heading level0 col1" >densired16</th>
#       <th id="T_d5e70_level0_col2" class="col_heading level0 col2" >densired32</th>
#       <th id="T_d5e70_level0_col3" class="col_heading level0 col3" >densired64</th>
#       <th id="T_d5e70_level0_col4" class="col_heading level0 col4" >densired_soft_8</th>
#       <th id="T_d5e70_level0_col5" class="col_heading level0 col5" >densired_soft_16</th>
#       <th id="T_d5e70_level0_col6" class="col_heading level0 col6" >densired_soft_32</th>
#       <th id="T_d5e70_level0_col7" class="col_heading level0 col7" >densired_soft_64</th>
#       <th id="T_d5e70_level0_col8" class="col_heading level0 col8" >mnist8</th>
#       <th id="T_d5e70_level0_col9" class="col_heading level0 col9" >mnist16</th>
#       <th id="T_d5e70_level0_col10" class="col_heading level0 col10" >mnist32</th>
#       <th id="T_d5e70_level0_col11" class="col_heading level0 col11" >mnist64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5e70_level0_row0" class="row_heading level0 row0" >Agglomerative
# Clustering</th>
#       <td id="T_d5e70_row0_col0" class="data row0 col0" >0.68</td>
#       <td id="T_d5e70_row0_col1" class="data row0 col1" >0.66</td>
#       <td id="T_d5e70_row0_col2" class="data row0 col2" >0.59</td>
#       <td id="T_d5e70_row0_col3" class="data row0 col3" >0.75</td>
#       <td id="T_d5e70_row0_col4" class="data row0 col4" >0.56</td>
#       <td id="T_d5e70_row0_col5" class="data row0 col5" >0.87</td>
#       <td id="T_d5e70_row0_col6" class="data row0 col6" >0.90</td>
#       <td id="T_d5e70_row0_col7" class="data row0 col7" >0.64</td>
#       <td id="T_d5e70_row0_col8" class="data row0 col8" >0.80</td>
#       <td id="T_d5e70_row0_col9" class="data row0 col9" >0.68</td>
#       <td id="T_d5e70_row0_col10" class="data row0 col10" >0.62</td>
#       <td id="T_d5e70_row0_col11" class="data row0 col11" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_d5e70_level0_row1" class="row_heading level0 row1" >HDBSCAN</th>
#       <td id="T_d5e70_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_d5e70_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_d5e70_row1_col2" class="data row1 col2" >0.44</td>
#       <td id="T_d5e70_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_d5e70_row1_col4" class="data row1 col4" >0.01</td>
#       <td id="T_d5e70_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_d5e70_row1_col6" class="data row1 col6" >0.00</td>
#       <td id="T_d5e70_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_d5e70_row1_col8" class="data row1 col8" >0.03</td>
#       <td id="T_d5e70_row1_col9" class="data row1 col9" >0.06</td>
#       <td id="T_d5e70_row1_col10" class="data row1 col10" >0.07</td>
#       <td id="T_d5e70_row1_col11" class="data row1 col11" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_d5e70_level0_row2" class="row_heading level0 row2" >Gaussian
# Mixture</th>
#       <td id="T_d5e70_row2_col0" class="data row2 col0" >0.79</td>
#       <td id="T_d5e70_row2_col1" class="data row2 col1" >0.77</td>
#       <td id="T_d5e70_row2_col2" class="data row2 col2" >0.69</td>
#       <td id="T_d5e70_row2_col3" class="data row2 col3" >0.91</td>
#       <td id="T_d5e70_row2_col4" class="data row2 col4" >0.74</td>
#       <td id="T_d5e70_row2_col5" class="data row2 col5" >0.68</td>
#       <td id="T_d5e70_row2_col6" class="data row2 col6" >0.49</td>
#       <td id="T_d5e70_row2_col7" class="data row2 col7" >0.42</td>
#       <td id="T_d5e70_row2_col8" class="data row2 col8" >0.89</td>
#       <td id="T_d5e70_row2_col9" class="data row2 col9" >0.74</td>
#       <td id="T_d5e70_row2_col10" class="data row2 col10" >0.73</td>
#       <td id="T_d5e70_row2_col11" class="data row2 col11" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_d5e70_level0_row3" class="row_heading level0 row3" >t-Student
# Mixture</th>
#       <td id="T_d5e70_row3_col0" class="data row3 col0" >0.81</td>
#       <td id="T_d5e70_row3_col1" class="data row3 col1" >0.69</td>
#       <td id="T_d5e70_row3_col2" class="data row3 col2" >0.58</td>
#       <td id="T_d5e70_row3_col3" class="data row3 col3" >0.61</td>
#       <td id="T_d5e70_row3_col4" class="data row3 col4" >0.74</td>
#       <td id="T_d5e70_row3_col5" class="data row3 col5" >0.90</td>
#       <td id="T_d5e70_row3_col6" class="data row3 col6" >0.90</td>
#       <td id="T_d5e70_row3_col7" class="data row3 col7" >0.75</td>
#       <td id="T_d5e70_row3_col8" class="data row3 col8" >0.85</td>
#       <td id="T_d5e70_row3_col9" class="data row3 col9" >0.86</td>
#       <td id="T_d5e70_row3_col10" class="data row3 col10" >0.90</td>
#       <td id="T_d5e70_row3_col11" class="data row3 col11" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_d5e70_level0_row4" class="row_heading level0 row4" >Leiden</th>
#       <td id="T_d5e70_row4_col0" class="data row4 col0" >0.83</td>
#       <td id="T_d5e70_row4_col1" class="data row4 col1" >0.77</td>
#       <td id="T_d5e70_row4_col2" class="data row4 col2" >0.76</td>
#       <td id="T_d5e70_row4_col3" class="data row4 col3" >0.89</td>
#       <td id="T_d5e70_row4_col4" class="data row4 col4" >0.89</td>
#       <td id="T_d5e70_row4_col5" class="data row4 col5" >0.93</td>
#       <td id="T_d5e70_row4_col6" class="data row4 col6" >0.91</td>
#       <td id="T_d5e70_row4_col7" class="data row4 col7" >0.80</td>
#       <td id="T_d5e70_row4_col8" class="data row4 col8" >0.89</td>
#       <td id="T_d5e70_row4_col9" class="data row4 col9" >0.92</td>
#       <td id="T_d5e70_row4_col10" class="data row4 col10" >0.93</td>
#       <td id="T_d5e70_row4_col11" class="data row4 col11" >0.71</td>
#     </tr>
#     <tr>
#       <th id="T_d5e70_level0_row5" class="row_heading level0 row5" >TMM-NEB</th>
#       <td id="T_d5e70_row5_col0" class="data row5 col0" >0.92</td>
#       <td id="T_d5e70_row5_col1" class="data row5 col1" >1.00</td>
#       <td id="T_d5e70_row5_col2" class="data row5 col2" >0.94</td>
#       <td id="T_d5e70_row5_col3" class="data row5 col3" >0.96</td>
#       <td id="T_d5e70_row5_col4" class="data row5 col4" >0.89</td>
#       <td id="T_d5e70_row5_col5" class="data row5 col5" >0.94</td>
#       <td id="T_d5e70_row5_col6" class="data row5 col6" >0.94</td>
#       <td id="T_d5e70_row5_col7" class="data row5 col7" >0.74</td>
#       <td id="T_d5e70_row5_col8" class="data row5 col8" >0.77</td>
#       <td id="T_d5e70_row5_col9" class="data row5 col9" >0.92</td>
#       <td id="T_d5e70_row5_col10" class="data row5 col10" >0.79</td>
#       <td id="T_d5e70_row5_col11" class="data row5 col11" >0.64</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_nmi = nmi_table.style.apply(lambda x: x.apply(lambda y: color_top3(y, x))).format("{:.2f}")
styled_nmi
# Out:
# <style type="text/css">
# #T_1a533_row2_col1, #T_1a533_row2_col3, #T_1a533_row3_col0, #T_1a533_row3_col10, #T_1a533_row4_col0, #T_1a533_row4_col1, #T_1a533_row4_col2, #T_1a533_row4_col3, #T_1a533_row4_col6, #T_1a533_row4_col11, #T_1a533_row5_col5, #T_1a533_row5_col7 {
#   background-color: yellow;
# }
# #T_1a533_row2_col8, #T_1a533_row3_col11, #T_1a533_row4_col4, #T_1a533_row4_col5, #T_1a533_row4_col7, #T_1a533_row4_col8, #T_1a533_row4_col9, #T_1a533_row4_col10, #T_1a533_row5_col0, #T_1a533_row5_col1, #T_1a533_row5_col2, #T_1a533_row5_col3, #T_1a533_row5_col4, #T_1a533_row5_col6, #T_1a533_row5_col9 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1a533">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a533_level0_col0" class="col_heading level0 col0" >densired8</th>
#       <th id="T_1a533_level0_col1" class="col_heading level0 col1" >densired16</th>
#       <th id="T_1a533_level0_col2" class="col_heading level0 col2" >densired32</th>
#       <th id="T_1a533_level0_col3" class="col_heading level0 col3" >densired64</th>
#       <th id="T_1a533_level0_col4" class="col_heading level0 col4" >densired_soft_8</th>
#       <th id="T_1a533_level0_col5" class="col_heading level0 col5" >densired_soft_16</th>
#       <th id="T_1a533_level0_col6" class="col_heading level0 col6" >densired_soft_32</th>
#       <th id="T_1a533_level0_col7" class="col_heading level0 col7" >densired_soft_64</th>
#       <th id="T_1a533_level0_col8" class="col_heading level0 col8" >mnist8</th>
#       <th id="T_1a533_level0_col9" class="col_heading level0 col9" >mnist16</th>
#       <th id="T_1a533_level0_col10" class="col_heading level0 col10" >mnist32</th>
#       <th id="T_1a533_level0_col11" class="col_heading level0 col11" >mnist64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a533_level0_row0" class="row_heading level0 row0" >Agglomerative
# Clustering</th>
#       <td id="T_1a533_row0_col0" class="data row0 col0" >0.82</td>
#       <td id="T_1a533_row0_col1" class="data row0 col1" >0.82</td>
#       <td id="T_1a533_row0_col2" class="data row0 col2" >0.79</td>
#       <td id="T_1a533_row0_col3" class="data row0 col3" >0.84</td>
#       <td id="T_1a533_row0_col4" class="data row0 col4" >0.59</td>
#       <td id="T_1a533_row0_col5" class="data row0 col5" >0.81</td>
#       <td id="T_1a533_row0_col6" class="data row0 col6" >0.85</td>
#       <td id="T_1a533_row0_col7" class="data row0 col7" >0.71</td>
#       <td id="T_1a533_row0_col8" class="data row0 col8" >0.83</td>
#       <td id="T_1a533_row0_col9" class="data row0 col9" >0.78</td>
#       <td id="T_1a533_row0_col10" class="data row0 col10" >0.75</td>
#       <td id="T_1a533_row0_col11" class="data row0 col11" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_1a533_level0_row1" class="row_heading level0 row1" >HDBSCAN</th>
#       <td id="T_1a533_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_1a533_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_1a533_row1_col2" class="data row1 col2" >0.59</td>
#       <td id="T_1a533_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_1a533_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_1a533_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_1a533_row1_col6" class="data row1 col6" >0.01</td>
#       <td id="T_1a533_row1_col7" class="data row1 col7" >0.01</td>
#       <td id="T_1a533_row1_col8" class="data row1 col8" >0.06</td>
#       <td id="T_1a533_row1_col9" class="data row1 col9" >0.11</td>
#       <td id="T_1a533_row1_col10" class="data row1 col10" >0.14</td>
#       <td id="T_1a533_row1_col11" class="data row1 col11" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_1a533_level0_row2" class="row_heading level0 row2" >Gaussian
# Mixture</th>
#       <td id="T_1a533_row2_col0" class="data row2 col0" >0.83</td>
#       <td id="T_1a533_row2_col1" class="data row2 col1" >0.90</td>
#       <td id="T_1a533_row2_col2" class="data row2 col2" >0.84</td>
#       <td id="T_1a533_row2_col3" class="data row2 col3" >0.93</td>
#       <td id="T_1a533_row2_col4" class="data row2 col4" >0.73</td>
#       <td id="T_1a533_row2_col5" class="data row2 col5" >0.66</td>
#       <td id="T_1a533_row2_col6" class="data row2 col6" >0.56</td>
#       <td id="T_1a533_row2_col7" class="data row2 col7" >0.46</td>
#       <td id="T_1a533_row2_col8" class="data row2 col8" >0.89</td>
#       <td id="T_1a533_row2_col9" class="data row2 col9" >0.82</td>
#       <td id="T_1a533_row2_col10" class="data row2 col10" >0.81</td>
#       <td id="T_1a533_row2_col11" class="data row2 col11" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_1a533_level0_row3" class="row_heading level0 row3" >t-Student
# Mixture</th>
#       <td id="T_1a533_row3_col0" class="data row3 col0" >0.91</td>
#       <td id="T_1a533_row3_col1" class="data row3 col1" >0.84</td>
#       <td id="T_1a533_row3_col2" class="data row3 col2" >0.79</td>
#       <td id="T_1a533_row3_col3" class="data row3 col3" >0.79</td>
#       <td id="T_1a533_row3_col4" class="data row3 col4" >0.72</td>
#       <td id="T_1a533_row3_col5" class="data row3 col5" >0.82</td>
#       <td id="T_1a533_row3_col6" class="data row3 col6" >0.84</td>
#       <td id="T_1a533_row3_col7" class="data row3 col7" >0.71</td>
#       <td id="T_1a533_row3_col8" class="data row3 col8" >0.86</td>
#       <td id="T_1a533_row3_col9" class="data row3 col9" >0.87</td>
#       <td id="T_1a533_row3_col10" class="data row3 col10" >0.89</td>
#       <td id="T_1a533_row3_col11" class="data row3 col11" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_1a533_level0_row4" class="row_heading level0 row4" >Leiden</th>
#       <td id="T_1a533_row4_col0" class="data row4 col0" >0.91</td>
#       <td id="T_1a533_row4_col1" class="data row4 col1" >0.90</td>
#       <td id="T_1a533_row4_col2" class="data row4 col2" >0.90</td>
#       <td id="T_1a533_row4_col3" class="data row4 col3" >0.93</td>
#       <td id="T_1a533_row4_col4" class="data row4 col4" >0.82</td>
#       <td id="T_1a533_row4_col5" class="data row4 col5" >0.88</td>
#       <td id="T_1a533_row4_col6" class="data row4 col6" >0.86</td>
#       <td id="T_1a533_row4_col7" class="data row4 col7" >0.81</td>
#       <td id="T_1a533_row4_col8" class="data row4 col8" >0.89</td>
#       <td id="T_1a533_row4_col9" class="data row4 col9" >0.91</td>
#       <td id="T_1a533_row4_col10" class="data row4 col10" >0.91</td>
#       <td id="T_1a533_row4_col11" class="data row4 col11" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_1a533_level0_row5" class="row_heading level0 row5" >TMM-NEB</th>
#       <td id="T_1a533_row5_col0" class="data row5 col0" >0.93</td>
#       <td id="T_1a533_row5_col1" class="data row5 col1" >1.00</td>
#       <td id="T_1a533_row5_col2" class="data row5 col2" >0.95</td>
#       <td id="T_1a533_row5_col3" class="data row5 col3" >0.96</td>
#       <td id="T_1a533_row5_col4" class="data row5 col4" >0.82</td>
#       <td id="T_1a533_row5_col5" class="data row5 col5" >0.87</td>
#       <td id="T_1a533_row5_col6" class="data row5 col6" >0.88</td>
#       <td id="T_1a533_row5_col7" class="data row5 col7" >0.75</td>
#       <td id="T_1a533_row5_col8" class="data row5 col8" >0.85</td>
#       <td id="T_1a533_row5_col9" class="data row5 col9" >0.91</td>
#       <td id="T_1a533_row5_col10" class="data row5 col10" >0.86</td>
#       <td id="T_1a533_row5_col11" class="data row5 col11" >0.74</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_fm = fm_table.style.apply(lambda x: x.apply(lambda y: color_top3(y, x))).format("{:.2f}")
styled_fm
# Out:
# <style type="text/css">
# #T_6c310_row2_col1, #T_6c310_row2_col3, #T_6c310_row3_col7, #T_6c310_row3_col10, #T_6c310_row4_col0, #T_6c310_row4_col1, #T_6c310_row4_col2, #T_6c310_row4_col6, #T_6c310_row4_col11 {
#   background-color: yellow;
# }
# #T_6c310_row2_col8, #T_6c310_row3_col11, #T_6c310_row4_col4, #T_6c310_row4_col5, #T_6c310_row4_col7, #T_6c310_row4_col8, #T_6c310_row4_col9, #T_6c310_row4_col10, #T_6c310_row5_col0, #T_6c310_row5_col1, #T_6c310_row5_col2, #T_6c310_row5_col3, #T_6c310_row5_col4, #T_6c310_row5_col5, #T_6c310_row5_col6, #T_6c310_row5_col9 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6c310">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c310_level0_col0" class="col_heading level0 col0" >densired8</th>
#       <th id="T_6c310_level0_col1" class="col_heading level0 col1" >densired16</th>
#       <th id="T_6c310_level0_col2" class="col_heading level0 col2" >densired32</th>
#       <th id="T_6c310_level0_col3" class="col_heading level0 col3" >densired64</th>
#       <th id="T_6c310_level0_col4" class="col_heading level0 col4" >densired_soft_8</th>
#       <th id="T_6c310_level0_col5" class="col_heading level0 col5" >densired_soft_16</th>
#       <th id="T_6c310_level0_col6" class="col_heading level0 col6" >densired_soft_32</th>
#       <th id="T_6c310_level0_col7" class="col_heading level0 col7" >densired_soft_64</th>
#       <th id="T_6c310_level0_col8" class="col_heading level0 col8" >mnist8</th>
#       <th id="T_6c310_level0_col9" class="col_heading level0 col9" >mnist16</th>
#       <th id="T_6c310_level0_col10" class="col_heading level0 col10" >mnist32</th>
#       <th id="T_6c310_level0_col11" class="col_heading level0 col11" >mnist64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c310_level0_row0" class="row_heading level0 row0" >Agglomerative
# Clustering</th>
#       <td id="T_6c310_row0_col0" class="data row0 col0" >0.77</td>
#       <td id="T_6c310_row0_col1" class="data row0 col1" >0.76</td>
#       <td id="T_6c310_row0_col2" class="data row0 col2" >0.70</td>
#       <td id="T_6c310_row0_col3" class="data row0 col3" >0.82</td>
#       <td id="T_6c310_row0_col4" class="data row0 col4" >0.73</td>
#       <td id="T_6c310_row0_col5" class="data row0 col5" >0.91</td>
#       <td id="T_6c310_row0_col6" class="data row0 col6" >0.93</td>
#       <td id="T_6c310_row0_col7" class="data row0 col7" >0.79</td>
#       <td id="T_6c310_row0_col8" class="data row0 col8" >0.82</td>
#       <td id="T_6c310_row0_col9" class="data row0 col9" >0.72</td>
#       <td id="T_6c310_row0_col10" class="data row0 col10" >0.66</td>
#       <td id="T_6c310_row0_col11" class="data row0 col11" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_6c310_level0_row1" class="row_heading level0 row1" >HDBSCAN</th>
#       <td id="T_6c310_row1_col0" class="data row1 col0" >0.54</td>
#       <td id="T_6c310_row1_col1" class="data row1 col1" >0.54</td>
#       <td id="T_6c310_row1_col2" class="data row1 col2" >0.70</td>
#       <td id="T_6c310_row1_col3" class="data row1 col3" >0.54</td>
#       <td id="T_6c310_row1_col4" class="data row1 col4" >0.44</td>
#       <td id="T_6c310_row1_col5" class="data row1 col5" >0.43</td>
#       <td id="T_6c310_row1_col6" class="data row1 col6" >0.42</td>
#       <td id="T_6c310_row1_col7" class="data row1 col7" >0.39</td>
#       <td id="T_6c310_row1_col8" class="data row1 col8" >0.26</td>
#       <td id="T_6c310_row1_col9" class="data row1 col9" >0.29</td>
#       <td id="T_6c310_row1_col10" class="data row1 col10" >0.30</td>
#       <td id="T_6c310_row1_col11" class="data row1 col11" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_6c310_level0_row2" class="row_heading level0 row2" >Gaussian
# Mixture</th>
#       <td id="T_6c310_row2_col0" class="data row2 col0" >0.85</td>
#       <td id="T_6c310_row2_col1" class="data row2 col1" >0.84</td>
#       <td id="T_6c310_row2_col2" class="data row2 col2" >0.78</td>
#       <td id="T_6c310_row2_col3" class="data row2 col3" >0.94</td>
#       <td id="T_6c310_row2_col4" class="data row2 col4" >0.81</td>
#       <td id="T_6c310_row2_col5" class="data row2 col5" >0.77</td>
#       <td id="T_6c310_row2_col6" class="data row2 col6" >0.65</td>
#       <td id="T_6c310_row2_col7" class="data row2 col7" >0.62</td>
#       <td id="T_6c310_row2_col8" class="data row2 col8" >0.90</td>
#       <td id="T_6c310_row2_col9" class="data row2 col9" >0.77</td>
#       <td id="T_6c310_row2_col10" class="data row2 col10" >0.76</td>
#       <td id="T_6c310_row2_col11" class="data row2 col11" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_6c310_level0_row3" class="row_heading level0 row3" >t-Student
# Mixture</th>
#       <td id="T_6c310_row3_col0" class="data row3 col0" >0.87</td>
#       <td id="T_6c310_row3_col1" class="data row3 col1" >0.78</td>
#       <td id="T_6c310_row3_col2" class="data row3 col2" >0.69</td>
#       <td id="T_6c310_row3_col3" class="data row3 col3" >0.71</td>
#       <td id="T_6c310_row3_col4" class="data row3 col4" >0.81</td>
#       <td id="T_6c310_row3_col5" class="data row3 col5" >0.93</td>
#       <td id="T_6c310_row3_col6" class="data row3 col6" >0.93</td>
#       <td id="T_6c310_row3_col7" class="data row3 col7" >0.83</td>
#       <td id="T_6c310_row3_col8" class="data row3 col8" >0.86</td>
#       <td id="T_6c310_row3_col9" class="data row3 col9" >0.88</td>
#       <td id="T_6c310_row3_col10" class="data row3 col10" >0.91</td>
#       <td id="T_6c310_row3_col11" class="data row3 col11" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_6c310_level0_row4" class="row_heading level0 row4" >Leiden</th>
#       <td id="T_6c310_row4_col0" class="data row4 col0" >0.88</td>
#       <td id="T_6c310_row4_col1" class="data row4 col1" >0.84</td>
#       <td id="T_6c310_row4_col2" class="data row4 col2" >0.83</td>
#       <td id="T_6c310_row4_col3" class="data row4 col3" >0.92</td>
#       <td id="T_6c310_row4_col4" class="data row4 col4" >0.92</td>
#       <td id="T_6c310_row4_col5" class="data row4 col5" >0.95</td>
#       <td id="T_6c310_row4_col6" class="data row4 col6" >0.94</td>
#       <td id="T_6c310_row4_col7" class="data row4 col7" >0.87</td>
#       <td id="T_6c310_row4_col8" class="data row4 col8" >0.90</td>
#       <td id="T_6c310_row4_col9" class="data row4 col9" >0.93</td>
#       <td id="T_6c310_row4_col10" class="data row4 col10" >0.93</td>
#       <td id="T_6c310_row4_col11" class="data row4 col11" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_6c310_level0_row5" class="row_heading level0 row5" >TMM-NEB</th>
#       <td id="T_6c310_row5_col0" class="data row5 col0" >0.94</td>
#       <td id="T_6c310_row5_col1" class="data row5 col1" >1.00</td>
#       <td id="T_6c310_row5_col2" class="data row5 col2" >0.96</td>
#       <td id="T_6c310_row5_col3" class="data row5 col3" >0.97</td>
#       <td id="T_6c310_row5_col4" class="data row5 col4" >0.92</td>
#       <td id="T_6c310_row5_col5" class="data row5 col5" >0.95</td>
#       <td id="T_6c310_row5_col6" class="data row5 col6" >0.95</td>
#       <td id="T_6c310_row5_col7" class="data row5 col7" >0.82</td>
#       <td id="T_6c310_row5_col8" class="data row5 col8" >0.80</td>
#       <td id="T_6c310_row5_col9" class="data row5 col9" >0.93</td>
#       <td id="T_6c310_row5_col10" class="data row5 col10" >0.82</td>
#       <td id="T_6c310_row5_col11" class="data row5 col11" >0.67</td>
#     </tr>
#   </tbody>
# </table>

# %%
styled_vi = vi_table.style.apply(lambda x: x.apply(lambda y: color_min3(y, x))).format("{:.2f}")
styled_vi
# Out:
# <style type="text/css">
# #T_2a71b_row0_col7, #T_2a71b_row2_col1, #T_2a71b_row3_col0, #T_2a71b_row3_col10, #T_2a71b_row4_col0, #T_2a71b_row4_col1, #T_2a71b_row4_col2, #T_2a71b_row4_col3, #T_2a71b_row4_col6, #T_2a71b_row4_col11, #T_2a71b_row5_col4, #T_2a71b_row5_col5, #T_2a71b_row5_col9 {
#   background-color: yellow;
# }
# #T_2a71b_row2_col8, #T_2a71b_row3_col11, #T_2a71b_row4_col4, #T_2a71b_row4_col5, #T_2a71b_row4_col7, #T_2a71b_row4_col8, #T_2a71b_row4_col9, #T_2a71b_row4_col10, #T_2a71b_row5_col0, #T_2a71b_row5_col1, #T_2a71b_row5_col2, #T_2a71b_row5_col3, #T_2a71b_row5_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2a71b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a71b_level0_col0" class="col_heading level0 col0" >densired8</th>
#       <th id="T_2a71b_level0_col1" class="col_heading level0 col1" >densired16</th>
#       <th id="T_2a71b_level0_col2" class="col_heading level0 col2" >densired32</th>
#       <th id="T_2a71b_level0_col3" class="col_heading level0 col3" >densired64</th>
#       <th id="T_2a71b_level0_col4" class="col_heading level0 col4" >densired_soft_8</th>
#       <th id="T_2a71b_level0_col5" class="col_heading level0 col5" >densired_soft_16</th>
#       <th id="T_2a71b_level0_col6" class="col_heading level0 col6" >densired_soft_32</th>
#       <th id="T_2a71b_level0_col7" class="col_heading level0 col7" >densired_soft_64</th>
#       <th id="T_2a71b_level0_col8" class="col_heading level0 col8" >mnist8</th>
#       <th id="T_2a71b_level0_col9" class="col_heading level0 col9" >mnist16</th>
#       <th id="T_2a71b_level0_col10" class="col_heading level0 col10" >mnist32</th>
#       <th id="T_2a71b_level0_col11" class="col_heading level0 col11" >mnist64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a71b_level0_row0" class="row_heading level0 row0" >Agglomerative
# Clustering</th>
#       <td id="T_2a71b_row0_col0" class="data row0 col0" >0.55</td>
#       <td id="T_2a71b_row0_col1" class="data row0 col1" >0.56</td>
#       <td id="T_2a71b_row0_col2" class="data row0 col2" >0.66</td>
#       <td id="T_2a71b_row0_col3" class="data row0 col3" >0.49</td>
#       <td id="T_2a71b_row0_col4" class="data row0 col4" >0.95</td>
#       <td id="T_2a71b_row0_col5" class="data row0 col5" >0.50</td>
#       <td id="T_2a71b_row0_col6" class="data row0 col6" >0.41</td>
#       <td id="T_2a71b_row0_col7" class="data row0 col7" >0.65</td>
#       <td id="T_2a71b_row0_col8" class="data row0 col8" >0.78</td>
#       <td id="T_2a71b_row0_col9" class="data row0 col9" >1.00</td>
#       <td id="T_2a71b_row0_col10" class="data row0 col10" >1.12</td>
#       <td id="T_2a71b_row0_col11" class="data row0 col11" >1.57</td>
#     </tr>
#     <tr>
#       <th id="T_2a71b_level0_row1" class="row_heading level0 row1" >HDBSCAN</th>
#       <td id="T_2a71b_row1_col0" class="data row1 col0" >1.41</td>
#       <td id="T_2a71b_row1_col1" class="data row1 col1" >1.42</td>
#       <td id="T_2a71b_row1_col2" class="data row1 col2" >0.82</td>
#       <td id="T_2a71b_row1_col3" class="data row1 col3" >1.41</td>
#       <td id="T_2a71b_row1_col4" class="data row1 col4" >1.94</td>
#       <td id="T_2a71b_row1_col5" class="data row1 col5" >1.97</td>
#       <td id="T_2a71b_row1_col6" class="data row1 col6" >1.97</td>
#       <td id="T_2a71b_row1_col7" class="data row1 col7" >2.07</td>
#       <td id="T_2a71b_row1_col8" class="data row1 col8" >2.80</td>
#       <td id="T_2a71b_row1_col9" class="data row1 col9" >2.65</td>
#       <td id="T_2a71b_row1_col10" class="data row1 col10" >2.59</td>
#       <td id="T_2a71b_row1_col11" class="data row1 col11" >2.60</td>
#     </tr>
#     <tr>
#       <th id="T_2a71b_level0_row2" class="row_heading level0 row2" >Gaussian
# Mixture</th>
#       <td id="T_2a71b_row2_col0" class="data row2 col0" >0.51</td>
#       <td id="T_2a71b_row2_col1" class="data row2 col1" >0.31</td>
#       <td id="T_2a71b_row2_col2" class="data row2 col2" >0.52</td>
#       <td id="T_2a71b_row2_col3" class="data row2 col3" >0.20</td>
#       <td id="T_2a71b_row2_col4" class="data row2 col4" >0.79</td>
#       <td id="T_2a71b_row2_col5" class="data row2 col5" >0.94</td>
#       <td id="T_2a71b_row2_col6" class="data row2 col6" >1.16</td>
#       <td id="T_2a71b_row2_col7" class="data row2 col7" >1.32</td>
#       <td id="T_2a71b_row2_col8" class="data row2 col8" >0.52</td>
#       <td id="T_2a71b_row2_col9" class="data row2 col9" >0.80</td>
#       <td id="T_2a71b_row2_col10" class="data row2 col10" >0.86</td>
#       <td id="T_2a71b_row2_col11" class="data row2 col11" >1.15</td>
#     </tr>
#     <tr>
#       <th id="T_2a71b_level0_row3" class="row_heading level0 row3" >t-Student
# Mixture</th>
#       <td id="T_2a71b_row3_col0" class="data row3 col0" >0.27</td>
#       <td id="T_2a71b_row3_col1" class="data row3 col1" >0.51</td>
#       <td id="T_2a71b_row3_col2" class="data row3 col2" >0.67</td>
#       <td id="T_2a71b_row3_col3" class="data row3 col3" >0.68</td>
#       <td id="T_2a71b_row3_col4" class="data row3 col4" >0.82</td>
#       <td id="T_2a71b_row3_col5" class="data row3 col5" >0.48</td>
#       <td id="T_2a71b_row3_col6" class="data row3 col6" >0.45</td>
#       <td id="T_2a71b_row3_col7" class="data row3 col7" >0.74</td>
#       <td id="T_2a71b_row3_col8" class="data row3 col8" >0.64</td>
#       <td id="T_2a71b_row3_col9" class="data row3 col9" >0.58</td>
#       <td id="T_2a71b_row3_col10" class="data row3 col10" >0.50</td>
#       <td id="T_2a71b_row3_col11" class="data row3 col11" >0.73</td>
#     </tr>
#     <tr>
#       <th id="T_2a71b_level0_row4" class="row_heading level0 row4" >Leiden</th>
#       <td id="T_2a71b_row4_col0" class="data row4 col0" >0.27</td>
#       <td id="T_2a71b_row4_col1" class="data row4 col1" >0.31</td>
#       <td id="T_2a71b_row4_col2" class="data row4 col2" >0.32</td>
#       <td id="T_2a71b_row4_col3" class="data row4 col3" >0.19</td>
#       <td id="T_2a71b_row4_col4" class="data row4 col4" >0.49</td>
#       <td id="T_2a71b_row4_col5" class="data row4 col5" >0.34</td>
#       <td id="T_2a71b_row4_col6" class="data row4 col6" >0.37</td>
#       <td id="T_2a71b_row4_col7" class="data row4 col7" >0.47</td>
#       <td id="T_2a71b_row4_col8" class="data row4 col8" >0.52</td>
#       <td id="T_2a71b_row4_col9" class="data row4 col9" >0.41</td>
#       <td id="T_2a71b_row4_col10" class="data row4 col10" >0.40</td>
#       <td id="T_2a71b_row4_col11" class="data row4 col11" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_2a71b_level0_row5" class="row_heading level0 row5" >TMM-NEB</th>
#       <td id="T_2a71b_row5_col0" class="data row5 col0" >0.21</td>
#       <td id="T_2a71b_row5_col1" class="data row5 col1" >0.01</td>
#       <td id="T_2a71b_row5_col2" class="data row5 col2" >0.15</td>
#       <td id="T_2a71b_row5_col3" class="data row5 col3" >0.11</td>
#       <td id="T_2a71b_row5_col4" class="data row5 col4" >0.50</td>
#       <td id="T_2a71b_row5_col5" class="data row5 col5" >0.36</td>
#       <td id="T_2a71b_row5_col6" class="data row5 col6" >0.32</td>
#       <td id="T_2a71b_row5_col7" class="data row5 col7" >0.74</td>
#       <td id="T_2a71b_row5_col8" class="data row5 col8" >0.67</td>
#       <td id="T_2a71b_row5_col9" class="data row5 col9" >0.43</td>
#       <td id="T_2a71b_row5_col10" class="data row5 col10" >0.63</td>
#       <td id="T_2a71b_row5_col11" class="data row5 col11" >1.16</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(format_latex_output(styled_ari.to_latex(convert_css=True)))
# Out:
# \begin{tabular}{lrrrrrrrrrrrr}
#  & densired8 & densired16 & densired32 & densired64 & densired_soft_8 & densired_soft_16 & densired_soft_32 & densired_soft_64 & mnist8 & mnist16 & mnist32 & mnist64 \\
# Agglomerative
# Clustering & 0.68 & 0.66 & 0.59 & 0.75 & 0.56 & 0.87 & 0.90 & 0.64 & 0.80 & 0.68 & 0.62 & 0.49 \\
# HDBSCAN & 0.00 & 0.00 & 0.44 & 0.00 & 0.01 & 0.00 & 0.00 & 0.00 & 0.03 & 0.06 & 0.07 & 0.07 \\
# Gaussian
# Mixture & 0.79 & \textit{0.77} & 0.69 & \textit{0.91} & 0.74 & 0.68 & 0.49 & 0.42 & \textbf{0.89} & 0.74 & 0.73 & 0.62 \\
# t-Student
# Mixture & 0.81 & 0.69 & 0.58 & 0.61 & 0.74 & 0.90 & 0.90 & \textit{0.75} & 0.85 & 0.86 & \textit{0.90} & \textbf{0.77} \\
# Leiden & \textit{0.83} & \textit{0.77} & \textit{0.76} & 0.89 & \textbf{0.89} & \textit{0.93} & \textit{0.91} & \textbf{0.80} & \textbf{0.89} & \textbf{0.92} & \textbf{0.93} & \textit{0.71} \\
# TMM-NEB & \textbf{0.92} & \textbf{1.00} & \textbf{0.94} & \textbf{0.96} & \textbf{0.89} & \textbf{0.94} & \textbf{0.94} & 0.74 & 0.77 & \textbf{0.92} & 0.79 & 0.64 \\
# \end{tabular}

# %%
print(format_latex_output(styled_nmi.to_latex(convert_css=True)))
# Out:
# \begin{tabular}{lrrrrrrrrrrrr}
#  & densired8 & densired16 & densired32 & densired64 & densired_soft_8 & densired_soft_16 & densired_soft_32 & densired_soft_64 & mnist8 & mnist16 & mnist32 & mnist64 \\
# Agglomerative
# Clustering & 0.82 & 0.82 & 0.79 & 0.84 & 0.59 & 0.81 & 0.85 & 0.71 & 0.83 & 0.78 & 0.75 & 0.65 \\
# HDBSCAN & 0.00 & 0.00 & 0.59 & 0.00 & 0.00 & 0.00 & 0.01 & 0.01 & 0.06 & 0.11 & 0.14 & 0.13 \\
# Gaussian
# Mixture & 0.83 & \textit{0.90} & 0.84 & \textit{0.93} & 0.73 & 0.66 & 0.56 & 0.46 & \textbf{0.89} & 0.82 & 0.81 & 0.75 \\
# t-Student
# Mixture & \textit{0.91} & 0.84 & 0.79 & 0.79 & 0.72 & 0.82 & 0.84 & 0.71 & 0.86 & 0.87 & \textit{0.89} & \textbf{0.84} \\
# Leiden & \textit{0.91} & \textit{0.90} & \textit{0.90} & \textit{0.93} & \textbf{0.82} & \textbf{0.88} & \textit{0.86} & \textbf{0.81} & \textbf{0.89} & \textbf{0.91} & \textbf{0.91} & \textit{0.80} \\
# TMM-NEB & \textbf{0.93} & \textbf{1.00} & \textbf{0.95} & \textbf{0.96} & \textbf{0.82} & \textit{0.87} & \textbf{0.88} & \textit{0.75} & 0.85 & \textbf{0.91} & 0.86 & 0.74 \\
# \end{tabular}

# %%
print(format_latex_output(styled_fm.to_latex(convert_css=True)))
# Out:
# \begin{tabular}{lrrrrrrrrrrrr}
#  & densired8 & densired16 & densired32 & densired64 & densired_soft_8 & densired_soft_16 & densired_soft_32 & densired_soft_64 & mnist8 & mnist16 & mnist32 & mnist64 \\
# Agglomerative
# Clustering & 0.77 & 0.76 & 0.70 & 0.82 & 0.73 & 0.91 & 0.93 & 0.79 & 0.82 & 0.72 & 0.66 & 0.55 \\
# HDBSCAN & 0.54 & 0.54 & 0.70 & 0.54 & 0.44 & 0.43 & 0.42 & 0.39 & 0.26 & 0.29 & 0.30 & 0.30 \\
# Gaussian
# Mixture & 0.85 & \textit{0.84} & 0.78 & \textit{0.94} & 0.81 & 0.77 & 0.65 & 0.62 & \textbf{0.90} & 0.77 & 0.76 & 0.66 \\
# t-Student
# Mixture & 0.87 & 0.78 & 0.69 & 0.71 & 0.81 & 0.93 & 0.93 & \textit{0.83} & 0.86 & 0.88 & \textit{0.91} & \textbf{0.79} \\
# Leiden & \textit{0.88} & \textit{0.84} & \textit{0.83} & 0.92 & \textbf{0.92} & \textbf{0.95} & \textit{0.94} & \textbf{0.87} & \textbf{0.90} & \textbf{0.93} & \textbf{0.93} & \textit{0.76} \\
# TMM-NEB & \textbf{0.94} & \textbf{1.00} & \textbf{0.96} & \textbf{0.97} & \textbf{0.92} & \textbf{0.95} & \textbf{0.95} & 0.82 & 0.80 & \textbf{0.93} & 0.82 & 0.67 \\
# \end{tabular}

# %%
print(format_latex_output(styled_vi.to_latex(convert_css=True)))
# Out:
# \begin{tabular}{lrrrrrrrrrrrr}
#  & densired8 & densired16 & densired32 & densired64 & densired_soft_8 & densired_soft_16 & densired_soft_32 & densired_soft_64 & mnist8 & mnist16 & mnist32 & mnist64 \\
# Agglomerative
# Clustering & 0.55 & 0.56 & 0.66 & 0.49 & 0.95 & 0.50 & 0.41 & \textit{0.65} & 0.78 & 1.00 & 1.12 & 1.57 \\
# HDBSCAN & 1.41 & 1.42 & 0.82 & 1.41 & 1.94 & 1.97 & 1.97 & 2.07 & 2.80 & 2.65 & 2.59 & 2.60 \\
# Gaussian
# Mixture & 0.51 & \textit{0.31} & 0.52 & 0.20 & 0.79 & 0.94 & 1.16 & 1.32 & \textbf{0.52} & 0.80 & 0.86 & 1.15 \\
# t-Student
# Mixture & \textit{0.27} & 0.51 & 0.67 & 0.68 & 0.82 & 0.48 & 0.45 & 0.74 & 0.64 & 0.58 & \textit{0.50} & \textbf{0.73} \\
# Leiden & \textit{0.27} & \textit{0.31} & \textit{0.32} & \textit{0.19} & \textbf{0.49} & \textbf{0.34} & \textit{0.37} & \textbf{0.47} & \textbf{0.52} & \textbf{0.41} & \textbf{0.40} & \textit{0.88} \\
# TMM-NEB & \textbf{0.21} & \textbf{0.01} & \textbf{0.15} & \textbf{0.11} & \textit{0.50} & \textit{0.36} & \textbf{0.32} & 0.74 & 0.67 & \textit{0.43} & 0.63 & 1.16 \\
# \end{tabular}
